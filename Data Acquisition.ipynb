# %%
import pandas as pd
import numpy as np
import math
import seaborn as sns

# %% [markdown]
# Load the dataset into a pandas DataFrame.

# %%
data=pd.read_csv('/content/All-Cricket-World-Cup-Centuries.csv')

# %%
data
# Out:
#      No.          Player  Runs  Balls  4s  6s     S/R           Team  \
# 0      1    Dennis Amiss   137    147  18   0   93.19        England
# 1      2    Glenn Turner  171*    201  16   2   85.07    New Zealand
# 2      3  Keith Fletcher   131    147  13   0   89.11        England
# 3      4     Alan Turner   101    113   9   1   89.38      Australia
# 4      5    Glenn Turner  114*    177  13   0   64.40    New Zealand
# ..   ...             ...   ...    ...  ..  ..     ...            ...
# 191  192  Angelo Mathews   113    128  10   2   88.28      Sri Lanka
# 192  193    Rohit Sharma   103     94  14   2  109.57          India
# 193  194        KL Rahul   111    118  11   1   94.06          India
# 194  195  Faf du Plessis   100     94   7   2  106.38   South Africa
# 195  196    David Warner   122    117  15   2  104.27      Australia
#
#         Opposition                                    Venue       Date Result
# 0            India                           Lord's, London  07-Jun-75    Won
# 1      East Africa     Edgbaston Cricket Ground, Birmingham  07-Jun-75    Won
# 2      New Zealand                 Trent Bridge, Nottingham  11-Jun-75    Won
# 3        Sri Lanka                         The Oval, London  11-Jun-75    Won
# 4            India  Old Trafford Cricket Ground, Manchester  14-Jun-75    Won
# ..             ...                                      ...        ...    ...
# 191          India                Headingley Stadium, Leeds  06-Jul-19   Lost
# 192      Sri Lanka                Headingley Stadium, Leeds  06-Jul-19    Won
# 193      Sri Lanka                Headingley Stadium, Leeds  06-Jul-19    Won
# 194      Australia  Old Trafford Cricket Ground, Manchester  06-Jul-19    Won
# 195   South Africa  Old Trafford Cricket Ground, Manchester  06-Jul-19   Lost
#
# [196 rows x 12 columns]

# %% [markdown]
# Print the summary statistics of the dataset

# %%
data.describe()
# Out:
#              No.       Balls          4s          6s         S/R
# count  196.00000  196.000000  196.000000  196.000000  196.000000
# mean    98.50000  119.500000   11.229592    2.530612  104.357908
# std     56.72448   23.796897    3.678537    2.616336   24.555550
# min      1.00000   53.000000    3.000000    0.000000   61.270000
# 25%     49.75000  103.000000    9.000000    1.000000   86.312500
# 50%     98.50000  121.500000   11.000000    2.000000  102.390000
# 75%    147.25000  136.000000   14.000000    4.000000  115.840000
# max    196.00000  201.000000   24.000000   17.000000  245.450000

# %% [markdown]
# Display the first few rows of the DataFrame to understand its structure

# %%
data.head(10)
# Out:
#    No.            Player  Runs  Balls  4s  6s     S/R          Team  \
# 0    1      Dennis Amiss   137    147  18   0   93.19       England
# 1    2      Glenn Turner  171*    201  16   2   85.07   New Zealand
# 2    3    Keith Fletcher   131    147  13   0   89.11       England
# 3    4       Alan Turner   101    113   9   1   89.38     Australia
# 4    5      Glenn Turner  114*    177  13   0   64.40   New Zealand
# 5    6       Clive Lloyd   102     85  12   2  120.00   West Indies
# 6    7  Gordon Greenidge  106*    173   9   1   61.27   West Indies
# 7    8      Viv Richards  138*    157  11   3   87.89   West Indies
# 8    9        Allan Lamb   102    105  12   2   97.14       England
# 9   10       David Gower   130    120  12   5  108.33       England
#
#      Opposition                                    Venue       Date Result
# 0         India                           Lord's, London  07-Jun-75    Won
# 1   East Africa     Edgbaston Cricket Ground, Birmingham  07-Jun-75    Won
# 2   New Zealand                 Trent Bridge, Nottingham  11-Jun-75    Won
# 3     Sri Lanka                         The Oval, London  11-Jun-75    Won
# 4         India  Old Trafford Cricket Ground, Manchester  14-Jun-75    Won
# 5     Australia                           Lord's, London  21-Jun-75    Won
# 6         India     Edgbaston Cricket Ground, Birmingham  09-Jun-79    Won
# 7       England                           Lord's, London  23-Jun-79    Won
# 8   New Zealand                         The Oval, London  09-Jun-83    Won
# 9     Sri Lanka                   County Ground, Taunton  11-Jun-83    Won

# %% [markdown]
# What is the size of the dataset? (Number of rows and columns)

# %%
data.shape
# Out:
# (196, 12)

# %% [markdown]
# What are the data types of each column?

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   No.         196 non-null    int64
#  1   Player      196 non-null    object
#  2   Runs        196 non-null    object
#  3   Balls       196 non-null    int64
#  4   4s          196 non-null    int64
#  5   6s          196 non-null    int64
#  6   S/R         196 non-null    float64
#  7   Team        196 non-null    object
#  8   Opposition  196 non-null    object
#  9   Venue       196 non-null    object
#  10  Date        196 non-null    object
#  11  Result      196 non-null    object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 18.5+ KB

# %% [markdown]
# Are there any missing values in the dataset? If so, which columns have
# missing values and how many?

# %%
data.isna().sum()
# Out:
# No.           0
# Player        0
# Runs          0
# Balls         0
# 4s            0
# 6s            0
# S/R           0
# Team          0
# Opposition    0
# Venue         0
# Date          0
# Result        0
# dtype: int64

# %% [markdown]
# What are the unique values in a categorical column of your choice? How
# many unique values are there?

# %%
data.nunique()
# Out:
# No.           196
# Player        117
# Runs           93
# Balls          84
# 4s             20
# 6s             13
# S/R           188
# Team           15
# Opposition     20
# Venue          76
# Date          142
# Result          3
# dtype: int64

# %%
e=data['Runs'].nunique()
f=data['Runs'].unique()
print(e)
print(f)
# Out:
# 93
# ['137' '171*' '131' '101' '114*' '102' '106*' '138*' '130' '110' '105*'
#  '119' '102*' '175*' '103*' '103' '142' '105' '181' '113' '100' '126*'
#  '115' '100*' '115*' '114' '119*' '188*' '127*' '104*' '126' '111' '161'
#  '145' '106' '107*' '140*' '183' '104' '132*' '120*' '113*' '116' '172*'
#  '120' '141' '143*' '143' '134*' '152' '112*' '121' '124' '111*' '128*'
#  '123' '109' '160' '158' '146' '149' '175' '134' '131*' '133' '144' '107'
#  '108*' '135' '128' '215' '133*' '161*' '162*' '139*' '117*' '159' '178'
#  '156' '112' '138' '110*' '101*' '237*' '122*' '153' '117' '140' '124*'
#  '148' '166' '118' '122']

# %% [markdown]
# For a numerical column of your choice, calculate the mean, median, and
# standard deviation

# %%
d=data['S/R'].mean()
e=data['S/R'].median()
f=data['S/R'].std()
print(d)
print(e)
print(f)
# Out:
# 104.35790816326531
# 102.39
# 24.55554979751399

# %% [markdown]
# Identify any potential outliers in a numerical column of your choice. Explain
# your approach.

# %% [markdown]
# Find the correlation between numerical columns and discuss any interesting
# relationships.

# %%
data_num=data.select_dtypes(include=['int64','float64'])
data_num.head(5)
# Out:
#    No.  Balls  4s  6s    S/R
# 0    1    147  18   0  93.19
# 1    2    201  16   2  85.07
# 2    3    147  13   0  89.11
# 3    4    113   9   1  89.38
# 4    5    177  13   0  64.40

# %%
corr_matrix=data_num.corr()
corr_matrix
# Out:
#             No.     Balls        4s        6s       S/R
# No.    1.000000 -0.389509  0.093083  0.167243  0.315552
# Balls -0.389509  1.000000  0.171794 -0.187631 -0.625517
# 4s     0.093083  0.171794  1.000000 -0.003132  0.268429
# 6s     0.167243 -0.187631 -0.003132  1.000000  0.662114
# S/R    0.315552 -0.625517  0.268429  0.662114  1.000000

# %% [markdown]
# Group the data by a categorical column and compute the aggregate statistics
# (e.g., mean, sum) for a numerical column.

# %%
d=data.groupby('Player')[['Balls','4s','6s']].sum()
d
# Out:
#                      Balls  4s  6s
# Player
# AB de Villiers         399  50  19
# Aamer Sohail           275  20   0
# Aaron Finch            376  38  10
# Adam Gilchrist         104  13   8
# Ajay Jadeja            138   7   2
# ...                    ...  ..  ..
# Virender Sehwag        227  31   8
# Viv Richards           428  33  11
# William Porterfield    131  11   1
# Yuvraj Singh           123  10   2
# Zaheer Abbas           121   6   0
#
# [117 rows x 3 columns]

# %%
data['Runs'].max()
# Out:
# '237*'

# %%
d.sort_values(by='Balls')
# Out:
#                   Balls  4s  6s
# Player
# Glenn Maxwell        53  10   4
# Kevin O'Brien        63  13   6
# Eoin Morgan          71   4  17
# Paul Stirling        72  14   2
# Jos Buttler          76   9   2
# ...                 ...  ..  ..
# David Warner        508  59  13
# Sourav Ganguly      511  39  18
# Ricky Ponting       553  33  19
# Rohit Sharma        677  77  15
# Sachin Tendulkar    743  75  17
#
# [117 rows x 3 columns]

# %% [markdown]
# Based on your analysis, provide a brief summary of any insights or patterns
# you discovered in the dataset

# %%
In this dataset there is a total of 196 row and 12 columns and 237 is the highest score taken by a player.And Sachin Thendulkar is the
 player who faced the maximum no.of balls 743 he took the most 6s and 4s.
